# %%
import sys
sys.path.insert(0, '..')

# %%
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
import numpy as np

# %%
from iactrace import (
    Telescope, Cylinder, MCIntegrator, HexagonalSensor, SquareSensor, 
    hexshow, plot_telescope_geometry
)

# %% [markdown]
# # New Design

# %%
# %%time
integrator = MCIntegrator(128)
telescope = Telescope.from_yaml('../configs/HESS/CT1.yaml', integrator, sampling_key = jax.random.key(42))
# Out:
# CPU times: user 10.7 s, sys: 1.23 s, total: 12 s
# Wall time: 10.8 s

# %%
telescope = telescope.unfreeze('mirror_positions')

# %%
telescope.trainable_fields
# Out:
# ['mirror_positions']
